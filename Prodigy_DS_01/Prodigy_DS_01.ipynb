# 6    9.443000e+03  1.021600e+04  1.101400e+04  1.183900e+04  1.269000e+04
# 7    9.335941e+07  9.576035e+07  9.826868e+07  1.008925e+08  1.036186e+08
# 8    1.334260e+05  1.409840e+05  1.488770e+05  1.570060e+05  1.653050e+05
# 9    2.034974e+07  2.068065e+07  2.102036e+07  2.136402e+07  2.170849e+07
# 10   1.904148e+06  1.971530e+06  2.039346e+06  2.106142e+06  2.171029e+06
# 11   2.008500e+04  2.062600e+04  2.127200e+04  2.194900e+04  2.265600e+04
# ...

# %% [markdown]
# # Plotting a bar chart

# %%
plt.figure(figsize=(30,30))
plt.bar(years,df[years].sum())
plt.xlabel("Year",size=40)
plt.xticks(rotation=45)
plt.ylabel("Population (Billion)",size=40)
plt.title("Total Population Per Year",size=50)
plt.show()

# %%
plt.figure(figsize=(30,30))
plt.barh(years,df[years].sum())
plt.xticks(rotation=45)
plt.xlabel("Population (Billion)",size=40)
plt.ylabel("Year",size=40)
plt.title("Total Population Per Year",size=50)
plt.show()

# %% [markdown]
# # Loading Data

# %%
df2=pd.read_csv("Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_586440.csv")

# %%
df2.shape
# Out:
# (265, 6)

# %%
df2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df2.drop("Unnamed: 5",axis=1,inplace=True)

# %%
df2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
df2.describe()
# Out:
#        Country Code                 Region  IncomeGroup  \
# count           265                    217          216
# unique          265                      7            4
# top             ABW  Europe & Central Asia  High income
# freq              1                     58           82
#
#                                              SpecialNotes TableName
# count                                                 126       265
# unique                                                111       265
# top     The reporting period for national accounts dat...     Aruba
# freq                                                    7         1

# %% [markdown]
# # Cleaning Data

# %%
df2.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# dtype: int64

# %%
df2_incomedata=df2[['Country Code','IncomeGroup']]

# %%
df2_incomedata.isna().sum()
# Out:
# Country Code     0
# IncomeGroup     49
# dtype: int64

# %%
df2_incomedata.dropna(inplace=True)

# %%
df2_incomedata.isna().sum()
# Out:
# Country Code    0
# IncomeGroup     0
# dtype: int64

# %%
df2_incomedata['Country Code'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI',
#        'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK',
#        'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN',
#        'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB',
#        'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM',
#        'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND',
#        'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN',
#        'KAZ', 'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAO',
#        'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX',
# ...

# %%
df2_incomedata['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Lower middle income',
#        'Upper middle income'], dtype=object)

# %%
df2_incomedata['IncomeGroup'].value_counts()
# Out:
# IncomeGroup
# High income            82
# Lower middle income    54
# Upper middle income    54
# Low income             26
# Name: count, dtype: int64

# %% [markdown]
# # Plotting a histogram

# %%
plt.hist(df2_incomedata['IncomeGroup'],color='Orange')
plt.xlabel("Income Group")
plt.ylabel("Number Of Countries")
plt.title('Distribution of Countries by Income Group')
plt.xticks(rotation=45)
plt.show()
